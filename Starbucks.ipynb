# %%
#!/usr/bin/env python
# coding: utf-8
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re
import sys
import urllib
import pandas as pd
import numpy as np
import googlemaps#!/usr/bin/env python
# coding: utf-8
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re
import sys
import urllib
import pandas as pd
import numpy as np
import googlemaps
import bs4 as bs
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import urllib

# %%
for i in range(1172,2200):    
    url="https://store.starbucks.co.jp/detail-"+str(i)+"/"
    source=urllib.urlopen(url)
    soup = bs.BeautifulSoup(source,'lxml')
    if soup.find_all('h3')[0].string==u'\u30da\u30fc\u30b8\u304c\u5b58\u5728\u3057\u307e\u305b\u3093\u3067\u3057\u305f\u3002':
        pass
    else:
        name=soup.find_all('h2')[0].string
        lister=soup.find_all("td", class_="detail")
        for l in lister:
            print(l.string)
            if l.string!=None:
                if re.match("^\n[0-9]+\-[0-9]+",l.string):
                    print("tada!")
                    address=l.string
        gmaps = googlemaps.Client(key='AIzaSyDLKJj-Tk36MeK8Lm0O2CR4C8NbuUoR3jI')
        geocode_result = gmaps.geocode(address)
        lon=geocode_result[0]["geometry"]["location"]["lng"]
        lat=geocode_result[0]["geometry"]["location"]["lat"]
        row=pd.DataFrame([name,address,lon,lat])
        try:
            df=pd.concat([df,row],axis=1)
        except NameError:
            df=row
        print(name)
        print(i,lon,lat)
# Out:
# None
#
#  不定休
#
# 厚木西インターチェンジ（下り）より　約3km
# None
#
# 259-1143
# 神奈川県
# 伊勢原市
# 下糟屋2008-1
#
# tada!
# 0463-97-2377
# 伊勢原成瀬店
#
# (1172, 139.3243701, 35.4084081)
# None
#
#  不定休
#
# None
# None
#
# 261-8535
# 千葉県
# 千葉市美浜区
# 豊砂1-5
# イオンモール幕張新都心ファミリーモール
# tada!
# 043-350-0117
# イオンモール幕張新都心ファミリーモール店
#
# (1173, 140.0300062, 35.6548974)
# None
#
#  不定休
#
# None
# None
#
# 321-0935
# 栃木県
# 宇都宮市
# 城東2-24-11
#
# tada!
# 028-610-1288
# 宇都宮城東店
#
# (1174, 139.9050191, 36.5495195)
# None
#
#  不定休
#
# None
# None
#
# 192-0083
# 東京都
# 八王子市
# 旭町1-1
# セレオ八王子
# tada!
# 042-686-3269
# セレオ八王子北館店
#
# (1175, 139.3392618, 35.6560541)
# None
#
#  不定休
#
# None
# None
#
# 780-0026
# 高知県
# 高知市
# 秦南町1-4-8
# イオンモール高知
# tada!
# 088-826-2212
# イオンモール高知店
#
# (1176, 133.5426803, 33.5763511)
# None
#
#  不定休
#
# 太田駅／出入口（高松琴平電鉄琴平線） 徒歩17分
# None
#
# 761-8073
# 香川県
# 高松市
# 太田下町3010-3
#
# tada!
# 087-864-6277
# 高松サン・フラワー通り店
#
# (1177, 134.0518798, 34.3040342)
# None
#
#  不定休
#
# 北勢中央公園口駅／出入口（三岐鉄道三岐線） 徒歩23分
# None
#
# ...

# %%
df.to_csv("starbucks.csv",encoding="utf-8")

# %%
for l in lister:
    print(l.string)
#     if l.string!=None&re.match("^[0-9]+\-[0-9]+r\n",l.string):
    if l.string!=None:
        if re.match("^\n[0-9]+\-[0-9]+",l.string):
            print("real value")
    else:
        pass
# Out:
# None
#
#  不定休
#
# None
# None
#
# 104-0061
# 東京都
# 中央区
# 銀座3-7-3
# 銀座オーミビル 1F
# real value
# 03-3567-5713
# 席予約システムについてはこちらから

# %%
a=soup.find_all("td", class_="detail")
for i in a:
    print(i.string==None)
# Out:
# True
# False
# True
# True
# False
# False
# False

# %%
re.match("^[0-9]+\-[0-9]+$","444-4444")

# %%
url="https://store.starbucks.co.jp"
#/detail-2151/
prefnames=[]
for n in range(0,46):  
    driver = webdriver.Chrome(executable_path=r'/Users/singo/anaconda3/chromedriver')
    driver.get(url) 
    prefs=driver.find_elements_by_css_selector('a.Directory-listLink')
#     prefnames.append(url+u"/"+prefs[n].text)
    t=prefs[n].text
    tt=urllib.quote(t.encode("utf-8"))
    prefnames.append(url+"/"+tt)
    print(prefnames)
    driver.close()
#     for i in range(0,len(cities)):
#         city=cities[i]
#         find_element_by_css_selector('a.Directory-listLink').click()
